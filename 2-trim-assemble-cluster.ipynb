# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
import shlex
from Bio.Seq import Seq
import subprocess
import os

# %%
#helper functions
def read_gff(path):
    df = pd.read_csv(path, index_col=False, sep='\t', header=None, comment="#")
    df.columns = ['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute']
    return df

def sys(command):
    """
    """
    print("-" * 10)
    print("Executing: %s" % command)
    process = subprocess.Popen(shlex.split(command),stdout=subprocess.PIPE,stderr=subprocess.PIPE, cwd="/home/juan/Desktop/juan/bio/gliadinas/")
    stdout, stderr = process.communicate()
    #print("Result: stdout: %s - stderr: %s" % (stdout, stderr))
    #print("-" * 10)
    if stderr:
        print(stderr)
    return stdout, stderr



def gff2FA(df_gff, path_sequence, windows, output):
    """Extract fasta files from annotations
    """
    fasta_seq = SeqIO.parse(path_genome, 'fasta')
    buffer_seqs = []
    cont = 0
    for record in fasta_seq:
        print(record.id)
        dff_extract = df_gff[df_gff.seqname == record.id]
        for key,val in dff_extract.iterrows():
            clean_seq = ''.join(str(record.seq).splitlines())
            if int(val.start) - windows < 0:
                start = 0
            else:
                start = int(val.start) - windows
            if int(val.end) + windows > len(clean_seq):
                end = len(clean_seq)
            else:
                end = int(val.end) + windows
            new_seq = clean_seq[start:end]
            att = val.attribute
            id = record.id + '_' + str(start) + '_' + str(end)
            desc = "seq_id:" + str(record.id)
            desc += " feature_start:" + str(val.start)
            desc += " feature_end:" + str(val.end)
            desc += " genome_start:" + str(start)
            desc += " genome_end:" + str(end)
            desc += " feature:" + str(val.feature)
            desc += " attributes:" + val.attribute
            seq = SeqRecord(Seq(new_seq), id=id, description=desc)
            buffer_seqs.append(seq)
            cont += 1
    SeqIO.write(buffer_seqs, output, "fasta")
    return buffer_seqs

# %%
adapters = "data/adapters_new_rc.fa"
path_output_dir = "data/clean/"
path_spades = "sw/SPAdes-3.13.0-Linux/bin/spades"
path_cutadapt = "sw/cutadapt-2.7/"
path_fastqc = "sw/FastQC/"
adapter_f = "AATGATACGGCGACCACCGAGATCTACAC"
adapter_r = "CAAGCAGAAGACGGCATACGAGAT"

# %%
sys("pwd")
# Out:
# ----------
# Executing: pwd
# (b'/home/juan/Desktop/juan/bio/gliadinas\n', b'')

# %%
# !rm -r data/clean/*
# Out:
# rm: cannot remove 'data/clean/*': No such file or directory

# %%
s = 86
for i in range(434, 536):
    sample_1 = "data/reads/sar{}-2019_S{}_L001_R1_001.fastq.gz".format(i,s)
    sample_2 = "data/reads/sar{}-2019_S{}_L001_R2_001.fastq.gz".format(i,s)
    cmd = "sw/TrimGalore-0.6.5/trim_galore --fastqc --paired {} {} --output_dir {} -a {} -a {}"
    cmd = cmd.format(sample_1, sample_2, path_output_dir, adapter_f, adapter_r)
    print(cmd)
    out, err = sys(cmd)
    s += 1
    #if err:
    #    break
# Out:
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar434-2019_S86_L001_R1_001.fastq.gz data/reads/sar434-2019_S86_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar434-2019_S86_L001_R1_001.fastq.gz data/reads/sar434-2019_S86_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar434-2019_S86_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar434-2019_S86_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar434-2019_S86_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar434-2019_S86_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar434-2019_S86_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.02 s (33 us/read; 1.80 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                     736\nReads with adapters:                       594 (80.7%)\nReads written (passing filters):           736 (100.0%)\n\nTotal basepairs processed:       184,736 bp\nQuality-trimmed:                  16,646 bp (9.0%)\nTotal written (filtered):        167,205 bp (90.5%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 594 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 34.5%\n  C: 20.5%\n  G: 41.1%\n  T: 3.9%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t313\t184.0\t0\t313\n2\t272\t46.0\t0\t272\n3\t8\t11.5\t0\t8\n4\t1\t2.9\t0\t1\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar434-2019_S86_L001_R1_001.fastq.gz\n=============================================\n736 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar434-2019_S86_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar434-2019_S86_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar434-2019_S86_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar435-2019_S87_L001_R1_001.fastq.gz data/reads/sar435-2019_S87_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar435-2019_S87_L001_R1_001.fastq.gz data/reads/sar435-2019_S87_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar435-2019_S87_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar435-2019_S87_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar435-2019_S87_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar435-2019_S87_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar435-2019_S87_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.03 s (32 us/read; 1.85 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                     906\nReads with adapters:                       670 (74.0%)\nReads written (passing filters):           906 (100.0%)\n\nTotal basepairs processed:       227,406 bp\nQuality-trimmed:                  24,507 bp (10.8%)\nTotal written (filtered):        201,903 bp (88.8%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 670 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 42.4%\n  C: 16.9%\n  G: 35.2%\n  T: 5.5%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t351\t226.5\t0\t351\n2\t312\t56.6\t0\t312\n3\t7\t14.2\t0\t7\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar435-2019_S87_L001_R1_001.fastq.gz\n=============================================\n906 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar435-2019_S87_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar435-2019_S87_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar435-2019_S87_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACG ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar436-2019_S88_L001_R1_001.fastq.gz data/reads/sar436-2019_S88_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar436-2019_S88_L001_R1_001.fastq.gz data/reads/sar436-2019_S88_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar436-2019_S88_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar436-2019_S88_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar436-2019_S88_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar436-2019_S88_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar436-2019_S88_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.03 s (40 us/read; 1.51 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                     724\nReads with adapters:                       507 (70.0%)\nReads written (passing filters):           724 (100.0%)\n\nTotal basepairs processed:       181,724 bp\nQuality-trimmed:                  17,047 bp (9.4%)\nTotal written (filtered):        163,890 bp (90.2%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 507 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 40.6%\n  C: 17.9%\n  G: 36.5%\n  T: 4.9%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t240\t181.0\t0\t240\n2\t256\t45.2\t0\t256\n3\t10\t11.3\t0\t10\n5\t1\t0.7\t0\t1\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar436-2019_S88_L001_R1_001.fastq.gz\n=============================================\n724 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar436-2019_S88_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar436-2019_S88_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar436-2019_S88_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequen ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar437-2019_S89_L001_R1_001.fastq.gz data/reads/sar437-2019_S89_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar437-2019_S89_L001_R1_001.fastq.gz data/reads/sar437-2019_S89_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar437-2019_S89_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar437-2019_S89_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar437-2019_S89_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar437-2019_S89_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar437-2019_S89_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.02 s (33 us/read; 1.81 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                     503\nReads with adapters:                       340 (67.6%)\nReads written (passing filters):           503 (100.0%)\n\nTotal basepairs processed:       126,253 bp\nQuality-trimmed:                  22,682 bp (18.0%)\nTotal written (filtered):        103,060 bp (81.6%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 340 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 40.6%\n  C: 15.0%\n  G: 39.7%\n  T: 4.7%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\
sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar441-2019_S93_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar441-2019_S93_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar441-2019_S93_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACG ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar442-2019_S94_L001_R1_001.fastq.gz data/reads/sar442-2019_S94_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar442-2019_S94_L001_R1_001.fastq.gz data/reads/sar442-2019_S94_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar442-2019_S94_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar442-2019_S94_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar442-2019_S94_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar442-2019_S94_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar442-2019_S94_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.04 s (41 us/read; 1.47 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                   1,093\nReads with adapters:                       906 (82.9%)\nReads written (passing filters):         1,093 (100.0%)\n\nTotal basepairs processed:       274,343 bp\nQuality-trimmed:                  20,516 bp (7.5%)\nTotal written (filtered):        252,454 bp (92.0%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 906 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 38.6%\n  C: 16.7%\n  G: 40.3%\n  T: 4.4%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t448\t273.2\t0\t448\n2\t449\t68.3\t0\t449\n3\t9\t17.1\t0\t9\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar442-2019_S94_L001_R1_001.fastq.gz\n=============================================\n1093 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar442-2019_S94_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar442-2019_S94_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar442-2019_S94_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACG ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar443-2019_S95_L001_R1_001.fastq.gz data/reads/sar443-2019_S95_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar443-2019_S95_L001_R1_001.fastq.gz data/reads/sar443-2019_S95_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar443-2019_S95_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar443-2019_S95_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar443-2019_S95_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar443-2019_S95_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar443-2019_S95_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.03 s (31 us/read; 1.92 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                     885\nReads with adapters:                       619 (69.9%)\nReads written (passing filters):           885 (100.0%)\n\nTotal basepairs processed:       222,135 bp\nQuality-trimmed:                  30,489 bp (13.7%)\nTotal written (filtered):        190,724 bp (85.9%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 619 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 36.0%\n  C: 20.7%\n  G: 37.5%\n  T: 5.8%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t327\t221.2\t0\t327\n2\t281\t55.3\t0\t281\n3\t11\t13.8\t0\t11\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar443-2019_S95_L001_R1_001.fastq.gz\n=============================================\n885 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar443-2019_S95_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar443-2019_S95_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar443-2019_S95_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGA ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar444-2019_S96_L001_R1_001.fastq.gz data/reads/sar444-2019_S96_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar444-2019_S96_L001_R1_001.fastq.gz data/reads/sar444-2019_S96_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar444-2019_S96_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar444-2019_S96_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar444-2019_S96_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar444-2019_S96_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar444-2019_S96_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.04 s (30 us/read; 1.97 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                   1,363\nReads with adapters:                     1,007 (73.9%)\nReads written (passing filters):         1,363 (100.0%)\n\nTotal basepairs processed:       342,113 bp\nQuality-trimmed:                  37,745 bp (11.0%)\nTotal written (filtered):        302,773 bp (88.5%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 1007 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 29.1%\n  C: 11.4%\n  G: 54.1%\n  T: 5.4%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t434\t340.8\t0\t434\n2\t559\t85.2\t0\t559\n3\t13\t21.3\t0\t13\n4\t1\t5.3\t0\t1\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar444-2019_S96_L001_R1_001.fastq.gz\n=============================================\n1363 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar444-2019_S96_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar444-2019_S96_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar444-2019_S96_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter seq ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar445-2019_S97_L001_R1_001.fastq.gz data/reads/sar445-2019_S97_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar445-2019_S97_L001_R1_001.fastq.gz data/reads/sar445-2019_S97_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar533-2019_S185_L001_R1_001.fastq.gz data/reads/sar533-2019_S185_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar533-2019_S185_L001_R1_001.fastq.gz data/reads/sar533-2019_S185_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar533-2019_S185_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar533-2019_S185_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar533-2019_S185_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar533-2019_S185_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar533-2019_S185_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.04 s (31 us/read; 1.94 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                   1,208\nReads with adapters:                     1,013 (83.9%)\nReads written (passing filters):         1,208 (100.0%)\n\nTotal basepairs processed:       303,208 bp\nQuality-trimmed:                  18,486 bp (6.1%)\nTotal written (filtered):        283,090 bp (93.4%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 1013 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 30.3%\n  C: 11.9%\n  G: 54.8%\n  T: 3.0%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t417\t302.0\t0\t417\n2\t574\t75.5\t0\t574\n3\t21\t18.9\t0\t21\n4\t1\t4.7\t0\t1\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar533-2019_S185_L001_R1_001.fastq.gz\n=============================================\n1208 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar533-2019_S185_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar533-2019_S185_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar533-2019_S185_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the ada ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar534-2019_S186_L001_R1_001.fastq.gz data/reads/sar534-2019_S186_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar534-2019_S186_L001_R1_001.fastq.gz data/reads/sar534-2019_S186_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar534-2019_S186_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar534-2019_S186_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar534-2019_S186_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar534-2019_S186_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar534-2019_S186_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.05 s (30 us/read; 2.02 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                   1,538\nReads with adapters:                     1,262 (82.1%)\nReads written (passing filters):         1,538 (100.0%)\n\nTotal basepairs processed:       386,038 bp\nQuality-trimmed:                  24,484 bp (6.3%)\nTotal written (filtered):        359,554 bp (93.1%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 1262 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 39.9%\n  C: 15.4%\n  G: 41.2%\n  T: 3.6%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t545\t384.5\t0\t545\n2\t698\t96.1\t0\t698\n3\t17\t24.0\t0\t17\n4\t2\t6.0\t0\t2\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar534-2019_S186_L001_R1_001.fastq.gz\n=============================================\n1538 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar534-2019_S186_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar534-2019_S186_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar534-2019_S186_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the ada ...
# sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar535-2019_S187_L001_R1_001.fastq.gz data/reads/sar535-2019_S187_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# ----------
# Executing: sw/TrimGalore-0.6.5/trim_galore --fastqc --paired data/reads/sar535-2019_S187_L001_R1_001.fastq.gz data/reads/sar535-2019_S187_L001_R2_001.fastq.gz --output_dir data/clean/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
# b"Multicore support not enabled. Proceeding with single-core trimming.\nPath to Cutadapt set as: 'cutadapt' (default)\nCutadapt seems to be working fine (tested command 'cutadapt --version')\nCutadapt version: 1.15\nsingle-core operation.\nNo quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)\n\nOutput will be written into the directory: /home/juan/Desktop/juan/bio/gliadinas/data/clean/\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar535-2019_S187_L001_R1_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar535-2019_S187_L001_R1_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j 1\nWriting final adapter and quality trimmed output to sar535-2019_S187_L001_R1_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' from file data/reads/sar535-2019_S187_L001_R1_001.fastq.gz <<< \nThis is cutadapt 1.15 with Python 3.6.8\nCommand line parameters: -j 1 -e 0.1 -q 20 -O 1 -a CAAGCAGAAGACGGCATACGAGAT data/reads/sar535-2019_S187_L001_R1_001.fastq.gz\nRunning on 1 core\nTrimming 1 adapter with at most 10.0% errors in single-end mode ...\nFinished in 0.04 s (31 us/read; 1.96 M reads/minute).\n\n=== Summary ===\n\nTotal reads processed:                   1,347\nReads with adapters:                     1,089 (80.8%)\nReads written (passing filters):         1,347 (100.0%)\n\nTotal basepairs processed:       338,097 bp\nQuality-trimmed:                  23,042 bp (6.8%)\nTotal written (filtered):        313,287 bp (92.7%)\n\n=== Adapter 1 ===\n\nSequence: CAAGCAGAAGACGGCATACGAGAT; Type: regular 3'; Length: 24; Trimmed: 1089 times.\n\nNo. of allowed errors:\n0-9 bp: 0; 10-19 bp: 1; 20-24 bp: 2\n\nBases preceding removed adapters:\n  A: 24.8%\n  C: 13.0%\n  G: 59.8%\n  T: 2.4%\n  none/other: 0.0%\n\nOverview of removed sequences\nlength\tcount\texpect\tmax.err\terror counts\n1\t428\t336.8\t0\t428\n2\t645\t84.2\t0\t645\n3\t15\t21.0\t0\t15\n5\t1\t1.3\t0\t1\n\n\nRUN STATISTICS FOR INPUT FILE: data/reads/sar535-2019_S187_L001_R1_001.fastq.gz\n=============================================\n1347 sequences processed in total\nThe length threshold of paired-end sequences gets evaluated later on (in the validation step)\n\nWriting report to '/home/juan/Desktop/juan/bio/gliadinas/data/clean/sar535-2019_S187_L001_R2_001.fastq.gz_trimming_report.txt'\n\nSUMMARISING RUN PARAMETERS\n==========================\nInput filename: data/reads/sar535-2019_S187_L001_R2_001.fastq.gz\nTrimming mode: paired-end\nTrim Galore version: 0.6.4_dev\nCutadapt version: 1.15\nNumber of cores used for trimming: 1\nQuality Phred score cutoff: 20\nQuality encoding type selected: ASCII+33\nAdapter sequence: 'CAAGCAGAAGACGGCATACGAGAT' (user defined)\nMaximum trimming error rate: 0.1 (default)\nMinimum required adapter overlap (stringency): 1 bp\nMinimum required sequence length for both reads before a sequence pair gets removed: 20 bp\nRunning FastQC on the data once trimming has completed\nOutput file(s) will be GZIP compressed\n\nCutadapt seems to be reasonably up-to-date. Setting -j -j 1\nWriting final adapter and quality trimmed output to sar535-2019_S187_L001_R2_001_trimmed.fq.gz\n\n\n  >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the ada ...

# %%
s = 86
for i in range(434, 536):
    sample_1 = "data/clean/sar{}-2019_S{}_L001_R1_001_val_1.fq.gz".format(i,s)
    sample_2 = "data/clean/sar{}-2019_S{}_L001_R2_001_val_2.fq.gz".format(i,s)
    output = "data/assembly/assembly-{}-2019_S{}_L001_R2_001.fasta".format(i,s)
    cmd = "/home/juan/Desktop/juan/bio/gliadinas/sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 {} -2 {} -o {}"
    cmd = cmd.format(sample_1, sample_2, output)
    out, err = sys(cmd)
    s += 1
    #if err:
    #    break
# Out:
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 data/clean/sar434-2019_S86_L001_R1_001_val_1.fq.gz -2 data/clean/sar434-2019_S86_L001_R2_001_val_2.fq.gz -o data/assembly/assembly-434-2019_S86_L001_R2_001.fasta
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 data/clean/sar435-2019_S87_L001_R1_001_val_1.fq.gz -2 data/clean/sar435-2019_S87_L001_R2_001_val_2.fq.gz -o data/assembly/assembly-435-2019_S87_L001_R2_001.fasta
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 data/clean/sar436-2019_S88_L001_R1_001_val_1.fq.gz -2 data/clean/sar436-2019_S88_L001_R2_001_val_2.fq.gz -o data/assembly/assembly-436-2019_S88_L001_R2_001.fasta
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 data/clean/sar437-2019_S89_L001_R1_001_val_1.fq.gz -2 data/clean/sar437-2019_S89_L001_R2_001_val_2.fq.gz -o data/assembly/assembly-437-2019_S89_L001_R2_001.fasta
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 data/clean/sar438-2019_S90_L001_R1_001_val_1.fq.gz -2 data/clean/sar438-2019_S90_L001_R2_001_val_2.fq.gz -o data/assembly/assembly-438-2019_S90_L001_R2_001.fasta
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 data/clean/sar439-2019_S91_L001_R1_001_val_1.fq.gz -2 data/clean/sar439-2019_S91_L001_R2_001_val_2.fq.gz -o data/assembly/assembly
fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-528-2019_S180_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-528-2019_S180.fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-529-2019_S181_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-529-2019_S181.fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-530-2019_S182_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-530-2019_S182.fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-531-2019_S183_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-531-2019_S183.fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-532-2019_S184_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-532-2019_S184.fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-533-2019_S185_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-533-2019_S185.fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-534-2019_S186_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-534-2019_S186.fasta -c 0.98
# ----------
# Executing: /home/juan/Desktop/juan/bio/gliadinas/sw/cd-hit-v4.8.1-2019-0228/cd-hit-est -i data/assembly/assembly-535-2019_S187_L001_R2_001.fasta/contigs.fasta -o data/clusters/cluster-535-2019_S187.fasta -c 0.98

# %%
#!/usr/bin/env bds

string adapters = "data/adapters_new_rc.fa"


sys export PATH=$PATH:$PWD/sw/SPAdes-3.13.0-Linux/bin
sys export PATH=$PATH:$PWD/sw/.bds
sys export PATH=$PATH:$PWD/sw/cutadapt-2.7
sys export PATH=$PATH:$PWD/sw/FastQC

sys rm -r data/clean_1/*
sys rm -r data/clean_2/*
sys rm -r data/clean_3/*
sys rm -r data/assembly/*

int s = 86
for( int i=434 ; i <= 535 ; i++ ) {

    string sample_1_1 = "data/reads/sar"+i+"-2019_S"+s+"_L001_R1_001.fastq.gz"
    string sample_2_1 = "data/reads/sar"+i+"-2019_S"+s+"_L001_R2_001.fastq.gz"
    try{
        sys sw/TrimGalore-0.6.5/trim_galore --paired $sample_1_1 $sample_2_1 --output_dir data/clean_1/
    }catch (Exception e){
        print "error in $sample_1_1 $sample_2_1\n"
    }
    

    string sample_1_2 = "data/clean_1/sar"+i+"-2019_S"+s+"_L001_R1_001_val_1.fq.gz"
    string sample_2_2 = "data/clean_1/sar"+i+"-2019_S"+s+"_L001_R2_001_val_2.fq.gz"
    try{
        sys sw/TrimGalore-0.6.5/trim_galore --fastqc --paired $sample_1_2 $sample_2_2 --output_dir data/clean_2/ -a AATGATACGGCGACCACCGAGATCTACAC -a CAAGCAGAAGACGGCATACGAGAT
    }catch (Exception e){
        print "error in $sample_1_2 $sample_2_2\n"
    }

    string sample_1_3 = "data/clean_2/sar"+i+"-2019_S"+s+"_L001_R1_001_val_1_val_1.fq.gz"
    string sample_2_3 = "data/clean_2/sar"+i+"-2019_S"+s+"_L001_R2_001_val_2_val_2.fq.gz"
    try{
        sys sw/TrimGalore-0.6.5/trim_galore --fastqc --paired $sample_1_3 $sample_2_3 --output_dir data/clean_3/ -a GTGTAGATCTCGGTGGTCGCCGTATCATT -a ATCTCGTATGCCGTCTTCTGCTTG
    }catch (Exception e){
        print "error in $sample_1_3 $sample_2_3\n"
    }

    string sample_1 = "data/clean_3/sar"+i+"-2019_S"+s+"_L001_R1_001_val_1_val_1_val_1.fq.gz"
    string sample_2 = "data/clean_3/sar"+i+"-2019_S"+s+"_L001_R2_001_val_2_val_2_val_2.fq.gz"
    string sample_out = "data/assembly/sar" + i + "-2019_S" + s + "/"
    
    sys sw/SPAdes-3.13.0-Linux/bin/spades.py --careful -1 $sample_1_3 -2 $sample_2_3 -o $sample_out

    s = s + 1
}
